# %%
# %load_ext autoreload

# %% [markdown]
# #  Taller En Clase ODE Método de Euler
# ## realizado por: Correa Adrian
# ## Fecha: 05/02/2025
# ## link de Github: https://github.com/afca2002/Taller-en-clase-ODE.git

# %% [markdown]
# ## Ejercicio 1
# $y'=y-t^2+1$
# * $0<=t<=2$
# * $y(t_0)=0.5$

# %%
# %autoreload 2
from src import ODE_euler
f = lambda t, y: y - t**2 + 1
y_t0 = 0.5

a = 0
b = 2

ys,ts, h = ODE_euler(a=a, b=b, y_t0=y_t0, f=f, N=10)
ys
# Out:
# [0.5,
#  0.8,
#  1.1520000000000001,
#  1.5504000000000002,
#  1.9884800000000002,
#  2.4581760000000004,
#  2.9498112000000005,
#  3.4517734400000006,
#  3.950128128000001,
#  4.428153753600001,
#  4.865784504320001]

# %%
import matplotlib.pyplot as plt

plt.plot(ts, ys, marker="o", linestyle=":", label=r"$\hat{y}$")
plt.xlabel("Time")
plt.ylabel("Y")
plt.title("Solución usando Método de Euler")
plt.legend()
plt.show()

# %% [markdown]
# ## Comparación con la solución real
# La solución real de la ecuación diferencial es:
# $y(t)=(t+1)^2-0.5e^t$
#
# * Grafique la solución real y la aproximación obtenida con el método de Euler en una misma gráfica.

# %% [markdown]
# # Compare para diferentes valores de N
# * $N = 15$
# * $N = 20$
# * $N = 50$

# %% [markdown]
# # Método de Taylor

# %%
# %autoreload 2
from src import ODE_euler_nth
f = lambda t, y: y - t**2 + 1
f_p = lambda t, y: f(t,y) - 2*t
f_2p = lambda t, y: f_p(t,y) - 2

y_t0 = 0.5

a = 0
b = 2

ys_nth,ts_nth, h = ODE_euler_nth(a=a, b=b, y_t0=y_t0, f=f, N=10,f_derivatives=[f_p])
ys_nth
# Out:
# [0.5,
#  0.8300000000000001,
#  1.2158000000000002,
#  1.652076,
#  2.13233272,
#  2.6486459183999997,
#  3.191348020448,
#  3.7486445849465597,
#  4.306146393634803,
#  4.8462986002344595,
#  5.347684292286041]

# %%
import matplotlib.pyplot as plt

plt.plot(ts, ys, marker="o", linestyle=":", label="Método de Euler")
plt.plot(
    ts_nth, ys_nth, marker="o", linestyle=":", label="Método de Taylor de 2do orden"
)
plt.xlabel("Tiempo")
plt.ylabel("Y")
plt.title("Comparación de métodos")
plt.legend()
plt.show()

# %% [markdown]
# ## Grafica Valor Real vs Valor Aproximado

# %%
# %autoreload 2
from src import ODE_euler
def f(t: float, y: float) -> float:
    return y - t**2 + 1  

a = 0.0
b = 2.0
y_t0 = 0.5
N = 10

y_values, t_values, h_value = ODE_euler(a = a, b= b, f= f, y_t0=y_t0, N=N)
# Out:
# [02-05 18:41:39][INFO] 2025-02-05 18:41:39.601749
# [02-05 18:41:39][INFO] 2025-02-05 18:41:39.721147
# [02-05 18:41:39][INFO] 2025-02-05 18:41:39.828175

# %%
import matplotlib.pyplot as plt
import numpy as np

def y_real(t):
    return (t+1)**2 -0.5*np.exp(t)
t_cont_real = np.linspace(a, b, 100)
y_cont_real = y_real(t_cont_real)

plt.plot(t_values, y_values, 'o-', label='Solucion Euler')
plt.plot(t_cont_real, y_cont_real, label='Solucion Real')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Real vs Aproximado')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Prueba con N = 5

# %%
a = 0.0
b = 2.0
y_t0 = 0.5
N = 5
y_values_5, t_values_5, h_value_5 = ODE_euler(a = a, b= b, f= f, y_t0=y_t0, N=N)
plt.plot(t_values_5, y_values_5, 'o-', label='Solucion Euler N = 5')
plt.plot(t_cont_real, y_cont_real, label='Solucion Real')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Real vs Aproximado')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Prueba con N = 10

# %%
# %autoreload 2
from src import ODE_euler
def f(t: float, y: float) -> float:
    return y - t**2 + 1  

a = 0.0
b = 2.0
y_t0 = 0.5
N = 10

y_values, t_values, h_value = ODE_euler(a = a, b= b, f= f, y_t0=y_t0, N=N)

# %%
import matplotlib.pyplot as plt
import numpy as np

def y_real(t):
    return (t+1)**2 -0.5*np.exp(t)

t_cont_real = np.linspace(a, b, 100)
y_cont_real = y_real(t_cont_real)


plt.plot(t_values, y_values, 'o-', label='Solucion Euler N = 10')
plt.plot(t_cont_real, y_cont_real, label='Solucion Real')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Real vs Aproximado')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Prueba con N = 15

# %%
a = 0.0
b = 2.0
y_t0 = 0.5
N = 15
y_values_15, t_values_15, h_value_15 = ODE_euler(a = a, b= b, f= f, y_t0=y_t0, N=N)
plt.plot(t_values_15, y_values_15, 'o-', label='Solucion Euler N = 15')
plt.plot(t_cont_real, y_cont_real, label='Solucion Real')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Real vs Aproximado')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Prueba Con N = 20

# %%
a = 0.0
b = 2.0
y_t0 = 0.5
N = 20
y_values_20, t_values_20, h_value_20 = ODE_euler(a = a, b= b, f= f, y_t0=y_t0, N=N)
plt.plot(t_values_20, y_values_20, 'o-', label='Solucion Euler N = 20')
plt.plot(t_cont_real, y_cont_real, label='Solucion Real')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Real vs Aproximado')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Prueba Con N = 50

# %%
a = 0.0
b = 2.0
y_t0 = 0.5
N = 50
y_values_50, t_values_50, h_value_50 = ODE_euler(a = a, b= b, f= f, y_t0=y_t0, N=N)
plt.plot(t_values_50, y_values_50, 'o-', label='Solucion Euler N = 50')
plt.plot(t_cont_real, y_cont_real, label='Solucion Real')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Real vs Aproximado')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Comparacion de las graficas con N= 10, 15, 50

# %%
plt.plot(t_values, y_values, 'o-', label='Solucion Euler N = 10')
plt.plot(t_values_20, y_values_20, 'o-', label='Solucion Euler N = 20')
plt.plot(t_values_50, y_values_50, 'o-', label='Solucion Euler N = 50')
plt.plot(t_cont_real, y_cont_real, label='Solucion Real')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Real vs Aproximado')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Comparación
# 1. **Precisión**:
#    - A medida que \(N\) aumenta (\(N = 10, 20, 50\)), las aproximaciones del método de Euler se acercan más a la solución real.
#    - Con \(N = 10\), hay un error notable en comparación con la solución real, pero este disminuye significativamente con \(N = 50\).
#
# 2. **Convergencia**:
#    - Las curvas aproximadas convergen hacia la solución real, confirmando que más pasos (mayor \(N\)) mejoran la precisión del método de Euler.
#
# 3. **Visualización**:
#    - Las diferencias entre las soluciones aproximadas y la real son más evidentes para \(N = 10\), mientras que con \(N = 50\) las gráficas son casi indistinguibles.

# %% [markdown]
# ## Grafica con N= 5 , 10 , 20

# %%
plt.plot(t_values, y_values, 'o-', label='Solucion Euler N = 10')
plt.plot(t_values_5, y_values_5, 'o-', label='Solucion Euler N = 5')
plt.plot(t_values_20, y_values_20, 'o-', label='Solucion Euler N = 20')
plt.plot(t_cont_real, y_cont_real, label='Solucion Real')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Real vs Aproximado')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Ejercicio 3

# %%
def f(t: float, y: float) -> float:
    return y/t - (y/t)**2 

a = 1.0
b = 2.0
y_t0 = 1.0
N = 10

y_values_eje3, t_values_eje3, h_value_eje3 = ODE_euler(a = a, b= b, f= f, y_t0=y_t0, N=N)

# %%
def y_real_eje3(t):
    return t/(1+np.log(t))

t_cont_real_eje3 = np.linspace(a, b, 100)
y_cont_real_eje3 = y_real_eje3(t_cont_real_eje3)


plt.plot(t_values_eje3, y_values_eje3, 'o-', label='Solucion Euler')
plt.plot(t_cont_real_eje3, y_cont_real_eje3, label='Solucion Real')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Real vs Aproximado ejercicio 3')
plt.legend()
plt.grid(True)
plt.show()
